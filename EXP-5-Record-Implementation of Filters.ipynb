# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image1=cv2.imread("doraemon.png")
image2=cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image2)
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(210.5), np.float64(238.5), np.float64(-0.5))

# %%
# 1. Smoothing Filters
# i) Averaging Filter (3x3)
kernel=np.ones((11,11),np.float32)/169  # Simple 3x3 averaging kernel

# %%
averaged_image = cv2.filter2D(image2, -1, kernel)  # Apply the filter

# %%
plt.imshow(averaged_image)
plt.title("Average Filter Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(210.5), np.float64(238.5), np.float64(-0.5))

# %%
# ii) Weighted Averaging Filter (3x3)
#weighted_kernel = np.array([[1, 2, 1], [2, 4, 2], [1, 2, 1]], np.float32)
#weighted_kernel = weighted_kernel / weighted_kernel.sum()
weighted_kernel1=np.array([[1,2,1],[2,4,2],[1,2,1]])/16
weighted_kernel = weighted_kernel / weighted_kernel.sum()  # Normalize the weights

# %%
weighted_image = cv2.filter2D(image2, -1, weighted_kernel)  # Apply the filter

# %%
plt.imshow(weighted_image, cmap='gray')
plt.title("Weighted Averaging Filter")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(210.5), np.float64(238.5), np.float64(-0.5))

# %%
gaussian_blur=cv2.GaussianBlur(image2,(33,33),0,0)

# %%
plt.imshow(gaussian_blur)
plt.title("Gaussian Blur")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(210.5), np.float64(238.5), np.float64(-0.5))

# %%
median=cv2.medianBlur(image2,13)

# %%
plt.imshow(median)
plt.title("Median Blur")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(210.5), np.float64(238.5), np.float64(-0.5))

# %%
# 2. Sharpening Filters
# i) Laplacian Kernel (3x3)
laplacian_kernel =np.array([[-1,-1,-1],[2,-2,1],[2,1,-1]])  # Laplacian kernel

# %%
laplacian_image = cv2.filter2D(image2, -1, laplacian_kernel)  # Apply the Laplacian

# %%
sharpened_laplacian_image = cv2.add(image2, laplacian_image)  # Sharpen the image

# %%
plt.imshow(laplacian_image)
plt.title("Laplacian Kernel")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(210.5), np.float64(238.5), np.float64(-0.5))

# %%
# ii) Laplacian Operator (Using OpenCV)
laplacian_operator_image = cv2.Laplacian(image2, cv2.CV_64F)  # Laplacian operator
laplacian_operator_image = cv2.convertScaleAbs(laplacian_operator_image)  # Convert to absolute values
sharpened_operator_image = cv2.add(image2, laplacian_operator_image)  # Sharpen the image

# %%
plt.imshow(laplacian_operator_image)
plt.title("Laplacian Operator")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(210.5), np.float64(238.5), np.float64(-0.5))
